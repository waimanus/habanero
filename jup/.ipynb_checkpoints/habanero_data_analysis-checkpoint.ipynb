# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
import time
import calendar
# %matplotlib inline

# %%
ls
# Out:
# bmeoutput_clean.csv           Thermoutput_clean2.csv  WiPi_gps_cropt.csv
# co2output_clean.csv           Thermoutput_clean.csv
# habanero_data_analysis.ipynb  UVoutput_clean.csv

# %%
therm = np.loadtxt('../prc/logged/Thermoutput_clean_ascii.csv', delimiter = ',', skiprows=2)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-25-17b11bf49ec8> in <module>()
# ----> 1 therm = np.loadtxt('../prc/logged/Thermoutput_clean_ascii.csv', delimiter = ',', skiprows=2)
#
# /usr/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     894                 fh = iter(bz2.BZ2File(fname))
#     895             elif sys.version_info[0] == 2:
# --> 896                 fh = iter(open(fname, 'U'))
#     897             else:
#     898                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: '../prc/logged/Thermoutput_clean_ascii.csv'

# %%
therm_time=therm[:,0]
therm_temp=therm[:,1]

# %%
# Raw temperature data from thermocouple on Chonk

plt.plot(therm_time, therm_temp, '.')
plt.xlim(260000, 290000)
# Out:
# (260000, 290000)

# %%
uv = np.loadtxt('UVoutput_clean2.csv', delimiter = ',', skiprows=21)

# %%
uv_time=uv[:,0]
uv_index=uv[:,1]

# %%
# Raw UV index data from the UV sensor on Chonk

plt.plot(uv_time, uv_index, '.')
plt.xlim(260000, 290000)
plt.ylim(0, 400)
plt.xlabel('Time (s)')
plt.ylabel('UV Index)')
# Out:
# Text(0,0.5,u'UV Index)')

# %%
plt.xlim(260000,290000)
plt.ylim(0, 50)
plt.plot(uv_time, uv_index, '.')

# %%
bme = np.loadtxt('bmeoutput_clean.csv', delimiter = ',', skiprows=1)

# %%
bme_time = bme[:,0]
bme_temp = bme[:,1]
bme_pressure = bme[:,2]
bme_humidity = bme[:,3]

# %%
plt.plot(bme_time, bme_temp)
plt.xlabel('Time (s)')
plt.ylabel('Temp (K)')
plt.title('BME280 Temperature Readings')
# Out:
# Text(0.5,1,u'BME280 Temperature Readings')

# %%
plt.plot(bme_time, bme_pressure)
plt.ylabel('Pressure (hPa)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
min(bme_pressure) #minimum pressure!
# Out:
# 14.539999999999999

# %%
plt.plot(bme_time, bme_humidity, '.')
plt.xlabel('Time (s)')
plt.ylabel('Humidity (%)')
plt.xlim(250000, 290000)
# Out:
# (250000, 290000)

# %%
co2 = np.loadtxt('co2output_clean.csv', delimiter = ',', skiprows=1)

# %%
co2_time = co2[:,0]
co2_content = co2[:,1]
co2_voc = co2[:,2]
co2_temp = co2[:,3]

# %%
plt.plot(co2_time, co2_content)

# %%
plt.plot(co2_time, co2_temp)
plt.xlim(260000, 290000)
# Out:
# (260000, 290000)

# %%
plt.figure(figsize=(12,8))
plt.plot(bme_time, bme_temp, '.', label='bme280')
plt.plot(therm_time, therm_temp, '.', label='thermocouple')
plt.xlim(260000, 290000)
plt.legend()
plt.xlabel('Time (s)')
plt.ylabel('Temperature (K)')
# Out:
# Text(0,0.5,u'Temperature (K)')

# %% [markdown]
# The thermocouple looks like it has something weird going on, there is no reason the temperature should be getting below -75. I'm gonna exclude any points that are below that point.

# %%
therm_array = []
for i,j in zip(therm_time, therm_temp):
    if j > -75:
        therm_array.append((i,j))
new_therm_time = [item[0] for item in therm_array]
new_therm_temp = [item[1] for item in therm_array]

# %%
plt.figure(figsize=(12,8))
plt.plot(bme_time, bme_temp, '.', label='bme280')
plt.plot(new_therm_time, new_therm_temp, '.', label='thermocouple')
plt.xlim(260000, 290000)
plt.xlabel('Time (s)')
plt.ylabel('Temperature')
plt.legend()
plt.xlabel('Time (s)')
plt.ylabel('Temperature (K)')
# Out:
# Text(0, 0.5, 'Temperature (K)')

# %%
data=[]
time_utc=[]
time_s=[]
alt=[]
with open('WiPi_gps_cropt.csv') as infile:
    for line in infile:
        formatted_line=line.strip().split(',')
        data.append(formatted_line)
        time_utc.append(formatted_line[3])
        time_s.append(formatted_line[4])
        alt.append(formatted_line[5])

# %%
alt_floats=[float(item) for item in alt[2:]]
time_utc_floats=[calendar.timegm(time.strptime(item.strip(), '%Y-%m-%dT%H:%M:%S.000Z')) for item in time_utc[2:]]

# %%
time_utc_floats
# Out:
# [1557595021,
#  1557595023,
#  1557595025,
#  1557595027,
#  1557595029,
#  1557595031,
#  1557595033,
#  1557595035,
#  1557595037,
#  1557595039,
#  1557595041,
#  1557595043,
#  1557595045,
#  1557595047,
#  1557595049,
#  1557595051,
#  1557595053,
#  1557595055,
#  1557595057,
#  1557595059,
#  1557595061,
#  1557595063,
#  1557595065,
#  1557595067,
#  1557595069,
#  1557595071,
#  1557595073,
#  1557595075,
#  1557595077,
#  1557595079,
#  1557595081,
#  1557595083,
#  1557595085,
#  1557595087,
#  1557595089,
#  1557595091,
#  1557595093,
#  1557595095,
#  1557595097,
#  1557595099,
#  1557595101,
#  1557595103,
#  1557595105,
#  1557595107,
#  1557595109,
#  1557595111,
#  1557595113,
#  1557595115,
#  1557595117,
#  1557595119,
#  1557595121,
#  1557595123,
#  1557595125,
#  1557595127,
#  1557595129,
#  1557595131,
#  1557595133,
#  1557595135,
#  1557595137,
#  1557595139,
#  1557595141,
#  1557595143,
#  1557595145,
#  1557595147,
#  1557595149,
#  1557595151,
# ...

# %%
plt.plot(time_utc_floats, alt_floats)
plt.xlabel('Time in Seconds since Epoch')
plt.ylabel('Altitude')
# Out:
# Text(0, 0.5, 'Altitude')

# %%
calendar.timegm(time.strptime('2019-05-11T17:17:35.000Z', '%Y-%m-%dT%H:%M:%S.000Z'))
# Out:
# 1557595055
